# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df1 = pd.read_csv('/Users/karthik_swasaka/Downloads/dataset 7/train.csv')

# %%
df1.head()
# Out:
#        ID Type_of_AC  Model  Cooling_Capacity  Avg_Temp           Room_SIze  \
# 0  795823      Split    1.5           6579.15        43              1873.5
# 1  506848     Window    1.1           6775.44        46  1603.8000000000002
# 2  441027   Portable    3.8           6995.22        29              4807.0
# 3  160677     Window    1.2           1863.68        39  1466.3999999999999
# 4  902932     Window    NaN           3089.04        40              3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           3         3.0          5.0            0      1.720    31.333333
# 1           4         4.0          1.0            0     18.000    29.500000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
# ...

# %% [markdown]
# # Data understanding using visulization

# %%
df1.shape
# Out:
# (15000, 15)

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  object
#  2   Model                       14130 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   13987 non-null  object
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 14103 non-null  object
#  8   Age_of_Unit                 14018 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        13506 non-null  object
# ...

# %%
df1.isnull().sum()
# Out:
# ID                               0
# Type_of_AC                       0
# Model                          870
# Cooling_Capacity                 0
# Avg_Temp                         0
# Room_SIze                     1013
# Num_People                       0
# Star_Rating                    897
# Age_of_Unit                    982
# Maintenance                      0
# Avg_Usage                        0
# Avg_AC_Temp                      0
# City                          1494
# Input_Power                    713
# Electricity_Consumption_AC       0
# dtype: int64

# %%
df1['Type_of_AC'].value_counts()
# Out:
# Portable    3786
# Ducted      3779
# Window      3733
# Split       3702
# Name: Type_of_AC, dtype: int64

# %%
df1['Model'].value_counts()

summary_stats = df1['Model'].describe()

# Plot a histogram
plt.hist(df1['Model'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Model")
plt.ylabel("Frequency")
plt.title("Model Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    14130.000000
# mean         2.749264
# std          1.838315
# min          1.000000
# 25%          1.700000
# 50%          2.500000
# 75%          3.300000
# max         15.600000
# Name: Model, dtype: float64

# %%
#df1['Cooling_Capacity'].distplot()
plt.hist(df1['Avg_Temp'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel('Avg_Temp')
plt.ylabel("Frequency")
plt.title(f"Avg_Temp Distribution")
plt.show()

# %%
plt.hist(df1['Cooling_Capacity'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel('Cooling_Capacity')
plt.ylabel("Frequency")
plt.title(f"Cooling_Capacity Distribution")
plt.show()

# %%
df1['Room_SIze'] = pd.to_numeric(df1['Room_SIze'], errors='coerce', downcast='integer')

# %%
df1.head()
# Out:
#        ID Type_of_AC  Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  795823      Split    1.5           6579.15        43     1873.5
# 1  506848     Window    1.1           6775.44        46     1603.8
# 2  441027   Portable    3.8           6995.22        29     4807.0
# 3  160677     Window    1.2           1863.68        39     1466.4
# 4  902932     Window    NaN           3089.04        40     3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           3         3.0          5.0            0      1.720    31.333333
# 1           4         4.0          1.0            0     18.000    29.500000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
#         City         Input_Power  Electricity_Consumption_AC
# ...

# %%
df1['Room_SIze'].isnull().sum()
# Out:
# 1029

# %%
type(df1['Room_SIze'])
# Out:
# pandas.core.series.Series

# %%
plt.hist(df1['Room_SIze'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel('Room_SIze')
plt.ylabel("Frequency")
plt.title(f"Room_SIze Distribution")
plt.show()

# %%
df1['Room_SIze'].describe()
# Out:
# count    1.397100e+04
# mean    -2.143993e+06
# std      1.465264e+08
# min     -1.000000e+10
# 25%      2.286400e+03
# 50%      3.300500e+03
# 75%      4.324200e+03
# max      5.842200e+03
# Name: Room_SIze, dtype: float64

# %%
feature_name = 'Room_SIze'  # Replace with your feature name

# Create a box plot
plt.boxplot(df1['Room_SIze'])
plt.ylabel('frequency')
plt.title(f"Room_SIze Distribution (Box Plot)")
plt.show()

# %%
x_values = range(len(df1))

# Extract the feature values
y_values = df1['Room_SIze']

# Create a scatter plot
plt.scatter(x_values, y_values)
plt.xlabel("Index or X-axis Label")
plt.ylabel('Room_SIze')
plt.title(f"Scatter Plot of Room_SIze")
plt.show()

# %%
summary_stats = df1['Room_SIze'].describe()

# Plot a histogram
plt.hist(df1['Room_SIze'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Room_SIze")
plt.ylabel("Frequency")
plt.title("Room_Size Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    1.397100e+04
# mean    -2.143993e+06
# std      1.465264e+08
# min     -1.000000e+10
# 25%      2.286400e+03
# 50%      3.300500e+03
# 75%      4.324200e+03
# max      5.842200e+03
# Name: Room_SIze, dtype: float64

# %%
df1.head()
# Out:
#        ID Type_of_AC  Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  795823      Split    1.5           6579.15        43     1873.5
# 1  506848     Window    1.1           6775.44        46     1603.8
# 2  441027   Portable    3.8           6995.22        29     4807.0
# 3  160677     Window    1.2           1863.68        39     1466.4
# 4  902932     Window    NaN           3089.04        40     3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           3         3.0          5.0            0      1.720    31.333333
# 1           4         4.0          1.0            0     18.000    29.500000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
#         City         Input_Power  Electricity_Consumption_AC
# ...

# %%
summary_stats = df1['Num_People'].describe()

# Plot a histogram
plt.hist(df1['Num_People'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Num_People")
plt.ylabel("Frequency")
plt.title("Num_People Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    15000.000000
# mean        19.164067
# std         15.988777
# min          2.000000
# 25%         10.000000
# 50%         16.000000
# 75%         25.000000
# max        250.000000
# Name: Num_People, dtype: float64

# %%
df1['Star_Rating'].value_counts()
# Out:
# 4.0      6777
# 5.0      4423
# 3.0      1943
# 2.0       768
# 1.0       170
# ?           5
# $$          4
# __          4
# .           4
# blank       3
# -10e9       1
# 1k          1
# Name: Star_Rating, dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  object
#  2   Model                       14130 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   13971 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 14103 non-null  object
#  8   Age_of_Unit                 14018 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        13506 non-null  object
# ...

# %%
df1['Age_of_Unit'].value_counts()
# Out:
# 0.0    2076
# 2.0    2045
# 5.0    2020
# 4.0    1990
# 6.0    1988
# 3.0    1988
# 1.0    1911
# Name: Age_of_Unit, dtype: int64

# %%
sns.countplot(data = df1, x = 'Age_of_Unit')
# Out:
# <Axes: xlabel='Age_of_Unit', ylabel='count'>

# %%
df1['Maintenance'].value_counts()
# Out:
# 0    11613
# 1     3387
# Name: Maintenance, dtype: int64

# %%
summary_stats = df1['Avg_Usage'].describe()

# Plot a histogram
plt.hist(df1['Avg_Usage'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Avg_Usage")
plt.ylabel("Frequency")
plt.title("Avg_Usage Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    15000.000000
# mean        11.225386
# std          5.328956
# min          0.000000
# 25%          7.390750
# 50%         11.618000
# 75%         15.756000
# max         19.996000
# Name: Avg_Usage, dtype: float64

# %%
summary_stats = df1['Avg_AC_Temp'].describe()

# Plot a histogram
plt.hist(df1['Avg_AC_Temp'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Avg_AC_Temp")
plt.ylabel("Frequency")
plt.title("Avg_AC_Temp Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    15000.000000
# mean        17.653861
# std          3.906928
# min         10.541667
# 25%         14.727273
# 50%         17.403704
# 75%         20.094122
# max         41.000000
# Name: Avg_AC_Temp, dtype: float64

# %%
df1['City'].value_counts()
# Out:
# Berlin       1910
# Sao Paolo    1802
# Moscow       1546
# Mumbai       1238
# Bucharest    1184
# Tokyo        1086
# Delhi         997
# Geneva        757
# Cape Town     740
# Seoul         736
# New York      725
# Cairo         558
# Prague        198
# __              7
# ?               5
# -10e9           5
# $$              4
# .               4
# blank           3
# 1k              1
# Name: City, dtype: int64

# %%
df1['Input_Power'] = pd.to_numeric(df1['Input_Power'], errors='coerce', downcast='float')

# %%
summary_stats = df1['Input_Power'].describe()

# Plot a histogram
plt.hist(df1['Input_Power'], bins=20)  # You can adjust the number of bins as needed
plt.xlabel("Input_Power")
plt.ylabel("Frequency")
plt.title("Input_Power Distribution")
plt.show()

# Display the summary statistics
print(summary_stats)
# Out:
# count    1.427600e+04
# mean    -2.098507e+06
# std      1.449446e+08
# min     -1.000000e+10
# 25%      2.811697e+03
# 50%      2.921268e+03
# 75%      3.035012e+03
# max      3.295937e+03
# Name: Input_Power, dtype: float64

# %% [markdown]
# # Dealing with null values

# %%
# Calculate the mean for each feature
mean_feature1 = df1['Model'].mean()
mean_feature2 = df1['Room_SIze'].mean()
mean_feature3 = df1['Input_Power'].mean()
# Replace NaN values with the means
df1['Model'].fillna(mean_feature1, inplace=True)
df1['Room_SIze'].fillna(mean_feature2, inplace=True)
df1['Input_Power'].fillna(mean_feature3, inplace=True)

# %%
df1['Star_Rating'].fillna(4.0, inplace=True)

# %%
df1['Age_of_Unit'].fillna(3.0, inplace = True)

# %%
df1['City'].fillna("Missing", inplace=True)

# %%
df1.isnull().sum()
# Out:
# ID                            0
# Type_of_AC                    0
# Model                         0
# Cooling_Capacity              0
# Avg_Temp                      0
# Room_SIze                     0
# Num_People                    0
# Star_Rating                   0
# Age_of_Unit                   0
# Maintenance                   0
# Avg_Usage                     0
# Avg_AC_Temp                   0
# City                          0
# Input_Power                   0
# Electricity_Consumption_AC    0
# dtype: int64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  object
#  2   Model                       15000 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   15000 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 15000 non-null  object
#  8   Age_of_Unit                 15000 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        15000 non-null  object
# ...

# %% [markdown]
# # dealing with outliers

# %%
df1['City'].value_counts()
# Out:
# Berlin       1910
# Sao Paolo    1802
# Moscow       1546
# Missing      1494
# Mumbai       1238
# Bucharest    1184
# Tokyo        1086
# Delhi         997
# Geneva        757
# Cape Town     740
# Seoul         736
# New York      725
# Cairo         558
# Prague        198
# __              7
# ?               5
# -10e9           5
# $$              4
# .               4
# blank           3
# 1k              1
# Name: City, dtype: int64

# %%
import pandas as pd


# Step 1: Explore the categories and their frequencies
category_counts = df1['City'].value_counts()
print("Category Frequencies:")
print(category_counts)

# Step 2: Identify and handle infrequent categories (e.g., set a threshold)
threshold = 10  # You can adjust this threshold as needed

# Create a list of infrequent categories
infrequent_categories = category_counts[category_counts < threshold].index.tolist()

# Step 3: Replace infrequent categories with a new category label (e.g., "Other")
df1['City'] = df1['City'].apply(lambda x: 'Other' if x in infrequent_categories else x)
# Out:
# Category Frequencies:
# Berlin       1910
# Sao Paolo    1802
# Moscow       1546
# Missing      1494
# Mumbai       1238
# Bucharest    1184
# Tokyo        1086
# Delhi         997
# Geneva        757
# Cape Town     740
# Seoul         736
# New York      725
# Cairo         558
# Prague        198
# __              7
# ?               5
# -10e9           5
# $$              4
# .               4
# blank           3
# 1k              1
# Name: City, dtype: int64

# %%
df1['City'].value_counts()
# Out:
# Berlin       1910
# Sao Paolo    1802
# Moscow       1546
# Missing      1494
# Mumbai       1238
# Bucharest    1184
# Tokyo        1086
# Delhi         997
# Geneva        757
# Cape Town     740
# Seoul         736
# New York      725
# Cairo         558
# Prague        198
# Other          29
# Name: City, dtype: int64

# %%
category_counts = df1['Type_of_AC'].value_counts()
print("Category Frequencies:")
print(category_counts)
# Out:
# Category Frequencies:
# Portable    3786
# Ducted      3779
# Window      3733
# Split       3702
# Name: Type_of_AC, dtype: int64

# %%
category_counts = df1['Star_Rating'].value_counts()
print("Category Frequencies:")
print(category_counts)
# Out:
# Category Frequencies:
# 4.0      6777
# 5.0      4423
# 3.0      1943
# 4.0       897
# 2.0       768
# 1.0       170
# ?           5
# $$          4
# __          4
# .           4
# blank       3
# -10e9       1
# 1k          1
# Name: Star_Rating, dtype: int64

# %%
import pandas as pd

threshold = 170  # You can adjust this threshold as needed

# Create a list of infrequent categories
infrequent_categories = category_counts[category_counts < threshold].index.tolist()

# Step 3: Replace infrequent categories with a new category label (e.g., "Other")
df1['Star_Rating'] = df1['Star_Rating'].apply(lambda x: 'Other' if x in infrequent_categories else x)

# %%
df1['Star_Rating'].value_counts()
# Out:
# 4.0      6777
# 5.0      4423
# 3.0      1943
# 4.0       897
# 2.0       768
# 1.0       170
# Other      22
# Name: Star_Rating, dtype: int64

# %%
feature_to_analyze = 'Avg_AC_Temp'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
from scipy import stats
z_scores = stats.zscore(df1[feature_to_analyze])
threshold = 3  # You can adjust this threshold as needed

outliers = df1[abs(z_scores) > threshold]

# %%
plt.scatter(df1.index, df1[feature_to_analyze], label='Data')
plt.scatter(outliers.index, outliers[feature_to_analyze], color='red', label='Outliers')
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze} with Outliers')
plt.legend()
plt.show()

# %%
# Example: Winsorizing the data to cap the outliers
from scipy.stats.mstats import winsorize

df1['Avg_AC_Temp'] = winsorize(df1['Avg_AC_Temp'], limits=[0.05, 0.05])

# %%
feature_to_analyze = 'Avg_AC_Temp'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  object
#  2   Model                       15000 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   15000 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 15000 non-null  object
#  8   Age_of_Unit                 15000 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        15000 non-null  object
# ...

# %%
feature_to_analyze = 'Model'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# Example: Winsorizing the data to cap the outliers
from scipy.stats.mstats import winsorize

df1['Model'] = winsorize(df1['Model'], limits=[0.05, 0.05])

# %%
feature_to_analyze = 'Model'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Cooling_Capacity'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# Example: Winsorizing the data to cap the outliers
from scipy.stats.mstats import winsorize

df1['Cooling_Capacity'] = winsorize(df1['Cooling_Capacity'], limits=[0.05, 0.05])

# %%
feature_to_analyze = 'Cooling_Capacity'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Avg_Temp'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# Example: Winsorizing the data to cap the outliers
from scipy.stats.mstats import winsorize

df1['Avg_Temp'] = winsorize(df1['Avg_Temp'], limits=[0.05, 0.05])

# %%
feature_to_analyze = 'Avg_Temp'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Room_SIze'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Num_People'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
# Example: Winsorizing the data to cap the outliers
from scipy.stats.mstats import winsorize

df1['Num_People'] = winsorize(df1['Num_People'], limits=[0.05, 0.05])

# %%
feature_to_analyze = 'Num_People'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Age_of_Unit'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
df1['Age_of_Unit'].value_counts()
# Out:
# 3.0    2970
# 0.0    2076
# 2.0    2045
# 5.0    2020
# 4.0    1990
# 6.0    1988
# 1.0    1911
# Name: Age_of_Unit, dtype: int64

# %%
feature_to_analyze = 'Maintenance'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
df1['Maintenance'].value_counts()
# Out:
# 0    11613
# 1     3387
# Name: Maintenance, dtype: int64

# %%
feature_to_analyze = 'Avg_Usage'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Avg_AC_Temp'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %%
feature_to_analyze = 'Input_Power'

# Create a scatter plot
plt.scatter(df1.index, df1[feature_to_analyze])
plt.xlabel('Index')
plt.ylabel(feature_to_analyze)
plt.title(f'Scatter Plot of {feature_to_analyze}')
plt.show()

# %% [markdown]
# # Encoding

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  object
#  2   Model                       15000 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   15000 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 15000 non-null  object
#  8   Age_of_Unit                 15000 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        15000 non-null  object
# ...

# %%
sns. countplot(data =df1, x = 'Type_of_AC')
# Out:
# <Axes: xlabel='Type_of_AC', ylabel='count'>

# %%
df1['Type_of_AC'].value_counts()
# Out:
# Portable    3786
# Ducted      3779
# Window      3733
# Split       3702
# Name: Type_of_AC, dtype: int64

# %%
df = df1.copy()

# %%
# Perform frequency or count encoding
count_encoded = df['Type_of_AC'].value_counts()
# Map the count values back to the original DataFrame
df['Type_of_AC'] = df['Type_of_AC'].map(count_encoded)

df.head()
# Out:
#        ID  Type_of_AC     Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  795823        3702  1.500000           6579.15        43     1873.5
# 1  506848        3733  1.100000           6775.44        45     1603.8
# 2  441027        3786  3.800000           6995.22        29     4807.0
# 3  160677        3733  1.200000           1863.68        39     1466.4
# 4  902932        3733  2.749264           3089.04        40     3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           5         3.0          5.0            0      1.720    24.125000
# 1           5         4.0          1.0            0     18.000    24.125000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
#         City  Input_Power  Electricity_Consumption_AC
# ...

# %%
# Perform frequency or count encoding
count_encoded = df['City'].value_counts()
# Map the count values back to the original DataFrame
df['City'] = df['City'].map(count_encoded)

# %%
df.head()
# Out:
#        ID  Type_of_AC     Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  795823        3702  1.500000           6579.15        43     1873.5
# 1  506848        3733  1.100000           6775.44        45     1603.8
# 2  441027        3786  3.800000           6995.22        29     4807.0
# 3  160677        3733  1.200000           1863.68        39     1466.4
# 4  902932        3733  2.749264           3089.04        40     3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           5         3.0          5.0            0      1.720    24.125000
# 1           5         4.0          1.0            0     18.000    24.125000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
#    City  Input_Power  Electricity_Consumption_AC
# ...

# %%
df1.head()
# Out:
#        ID Type_of_AC     Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  795823      Split  1.500000           6579.15        43     1873.5
# 1  506848     Window  1.100000           6775.44        45     1603.8
# 2  441027   Portable  3.800000           6995.22        29     4807.0
# 3  160677     Window  1.200000           1863.68        39     1466.4
# 4  902932     Window  2.749264           3089.04        40     3139.4
#
#    Num_People Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0           5         3.0          5.0            0      1.720    24.125000
# 1           5         4.0          1.0            0     18.000    24.125000
# 2          38         4.0          1.0            0      0.551    13.763158
# 3          10         4.0          0.0            0     19.540    22.900000
# 4           9         5.0          4.0            0     16.760    18.444444
#
#         City  Input_Power  Electricity_Consumption_AC
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  int64
#  2   Model                       15000 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   15000 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 15000 non-null  object
#  8   Age_of_Unit                 15000 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        15000 non-null  int64
# ...

# %%
df['Star_Rating'].value_counts()
# Out:
# 4.0      6777
# 5.0      4423
# 3.0      1943
# 4.0       897
# 2.0       768
# 1.0       170
# Other      22
# Name: Star_Rating, dtype: int64

# %%
# Perform frequency or count encoding
count_encoded = df['Star_Rating'].value_counts()
# Map the count values back to the original DataFrame
df['Star_Rating'] = df['Star_Rating'].map(count_encoded)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 15 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          15000 non-null  int64
#  1   Type_of_AC                  15000 non-null  int64
#  2   Model                       15000 non-null  float64
#  3   Cooling_Capacity            15000 non-null  float64
#  4   Avg_Temp                    15000 non-null  int64
#  5   Room_SIze                   15000 non-null  float64
#  6   Num_People                  15000 non-null  int64
#  7   Star_Rating                 15000 non-null  int64
#  8   Age_of_Unit                 15000 non-null  float64
#  9   Maintenance                 15000 non-null  int64
#  10  Avg_Usage                   15000 non-null  float64
#  11  Avg_AC_Temp                 15000 non-null  float64
#  12  City                        15000 non-null  int64
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Type_of_AC', 'Model', 'Cooling_Capacity', 'Avg_Temp',
#        'Room_SIze', 'Num_People', 'Star_Rating', 'Age_of_Unit', 'Maintenance',
#        'Avg_Usage', 'Avg_AC_Temp', 'City', 'Input_Power',
#        'Electricity_Consumption_AC'],
#       dtype='object')

# %%
from sklearn.preprocessing import MinMaxScaler
# Extract the dependent variable (y) and independent features (X)
X = df.drop(columns=['Electricity_Consumption_AC'])
y = df['Electricity_Consumption_AC']

# Initialize the MinMaxScaler
scaler = MinMaxScaler()

# Fit and transform the independent features
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# The 'X_scaled' DataFrame now contains the scaled independent features
# Combine the scaled independent features with the dependent variable (y)
scaled_data = pd.concat([X_scaled, y], axis=1)

scaled_data.head()
# Out:
#          ID  Type_of_AC     Model  Cooling_Capacity  Avg_Temp  Room_SIze  \
# 0  0.773117    0.000000  0.142857          0.753006  0.882353        1.0
# 1  0.451988    0.369048  0.000000          0.782418  1.000000        1.0
# 2  0.378843    1.000000  0.964286          0.815349  0.058824        1.0
# 3  0.067298    0.369048  0.035714          0.046453  0.647059        1.0
# 4  0.892144    0.369048  0.589023          0.230057  0.705882        1.0
#
#    Num_People  Star_Rating  Age_of_Unit  Maintenance  Avg_Usage  Avg_AC_Temp  \
# 0    0.000000     0.284382     0.833333          0.0   0.086017     1.000000
# 1    0.000000     1.000000     0.166667          0.0   0.900180     1.000000
# 2    0.942857     1.000000     0.166667          0.0   0.027556     0.142978
# 3    0.142857     1.000000     0.000000          0.0   0.977195     0.898681
# 4    0.114286     0.651517     0.666667          0.0   0.838168     0.530164
#
#        City  Input_Power  Electricity_Consumption_AC
# ...

# %%
# Calculate the Pearson correlation coefficients between each feature and the dependent variable
correlation = df.corr()['Electricity_Consumption_AC']

# %%
print(correlation)
# Out:
# ID                           -0.004102
# Type_of_AC                    0.168790
# Model                         0.467633
# Cooling_Capacity              0.503297
# Avg_Temp                      0.253771
# Room_SIze                     0.005290
# Num_People                    0.347928
# Star_Rating                  -0.105576
# Age_of_Unit                   0.213117
# Maintenance                   0.211604
# Avg_Usage                     0.162492
# Avg_AC_Temp                  -0.150307
# City                          0.051511
# Input_Power                   0.004453
# Electricity_Consumption_AC    1.000000
# Name: Electricity_Consumption_AC, dtype: float64

# %%
correlation_matrix = df.corr()

# Create a heatmap to visualize the correlation matrix
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming you have a DataFrame named 'data' with your features
# Replace 'data' with your actual DataFrame name

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
def calculate_vif(data_frame):
    vif_data = pd.DataFrame()
    vif_data["Variable"] = data_frame.columns
    vif_data["VIF"] = [variance_inflation_factor(data_frame.values, i) for i in range(data_frame.shape[1])]
    return vif_data

vif_results = calculate_vif(df)
high_vif_features = vif_results[vif_results["VIF"] > 10]
print("Features with high VIF:", high_vif_features)

data_low_vif = df.drop(columns=high_vif_features["Variable"].to_list())
print("DataFrame after excluding high VIF features:")
data_low_vif.head()
# Out:
# Features with high VIF:                       Variable         VIF
# 1                   Type_of_AC  132.964311
# 2                        Model   16.302129
# 4                     Avg_Temp   73.769124
# 11                 Avg_AC_Temp   34.214225
# 14  Electricity_Consumption_AC   77.820917
# DataFrame after excluding high VIF features:
#        ID  Cooling_Capacity  Room_SIze  Num_People  Star_Rating  Age_of_Unit  \
# 0  795823           6579.15     1873.5           5         1943          5.0
# 1  506848           6775.44     1603.8           5         6777          1.0
# 2  441027           6995.22     4807.0          38         6777          1.0
# 3  160677           1863.68     1466.4          10         6777          0.0
# 4  902932           3089.04     3139.4           9         4423          4.0
#
#    Maintenance  Avg_Usage  City  Input_Power
# 0            0      1.720   558  2863.295166
# 1            0     18.000  1184  2783.309814
# ...

# %%
correlation = df.corr()['Electricity_Consumption_AC'].drop('Electricity_Consumption_AC')

# Create a bar graph to visualize the correlations
plt.figure(figsize=(20, 6))
correlation.plot(kind='bar', color='skyblue')
plt.title('Correlation with Dependent Variable')
plt.xlabel('Independent Variables')
plt.ylabel('Correlation')
plt.xticks(rotation=0)
plt.show()
